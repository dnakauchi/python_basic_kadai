# %%
class Human:

    def __init__(self):
        self.name = ""
        self.age = ""

    def printinfo(self,name,age):
        self.name = name
        self.age = age
        print(self.name,self.age)

Taro = Human()

Taro.printinfo("Taro",36)
# Out:
# Taro 36
