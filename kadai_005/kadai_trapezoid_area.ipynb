# %% [markdown]
# 上辺：10cm
# 下辺：20cm
# 高さ：5cm
#
# 公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2

# %%
top = 10.0
bot = 20.0
height = 5.0

area = (top+bot)*height/2.0

print("台形の面積 = "+str(area)+" cm^2")
# Out:
# 台形の面積 = 75.0cm^2
